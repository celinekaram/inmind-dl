# %% [markdown]
# # Clone the repository

# %%
# !git clone https://github.com/celinekaram/inmind-dl.git
# Out:
# Cloning into 'inmind-dl'...
# remote: Enumerating objects: 913, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 913 (delta 31), reused 40 (delta 16), pack-reused 854 (from 1)
# Receiving objects: 100% (913/913), 27.43 MiB | 37.20 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# !gdown --id 1pIXA3B_WCCd-Fyd-Z2sPHllaMt1nFqJD -O /content/data.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1pIXA3B_WCCd-Fyd-Z2sPHllaMt1nFqJD
# From (redirected): https://drive.google.com/uc?id=1pIXA3B_WCCd-Fyd-Z2sPHllaMt1nFqJD&confirm=t&uuid=946c3f18-1f37-44cd-a26f-179954e38311
# To: /content/data.zip
# 100% 1.23G/1.23G [00:17<00:00, 69.5MB/s]

# %%
import zipfile

zip_path = '/content/data.zip'
extract_dir = '/content/data/'

# Open the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the archive
    file_list = zip_ref.namelist()
    print("Files in the archive:", file_list)

    # Extract all files
    zip_ref.extractall(extract_dir)
    print(f"All files have been extracted to: {extract_dir}")
# Out:
# Files in the archive: ['out-2/', 'out-2/bounding_box_2d_tight_0001.npy', 'out-2/bounding_box_2d_tight_prim_paths_0001.json', 'out-2/semantic_segmentation_0002.png', 'out-2/semantic_segmentation_0003.png', 'out-2/bounding_box_2d_tight_0005.npy', 'out-2/rgb_0005.png', 'out-2/rgb_0006.png', 'out-2/semantic_segmentation_0007.png', 'out-2/bounding_box_2d_tight_labels_0009.json', 'out-2/bounding_box_2d_tight_labels_0013.json', 'out-2/semantic_segmentation_0014.png', 'out-2/bounding_box_2d_tight_labels_0017.json', 'out-2/bounding_box_2d_tight_0020.npy', 'out-2/semantic_segmentation_0020.png', 'out-2/rgb_0021.png', 'out-2/bounding_box_2d_tight_0022.npy', 'out-2/semantic_segmentation_labels_0022.json', 'out-2/bounding_box_2d_tight_0023.npy', 'out-2/bounding_box_2d_tight_labels_0023.json', 'out-2/bounding_box_2d_tight_prim_paths_0023.json', 'out-2/rgb_0023.png', 'out-2/semantic_segmentation_0024.png', 'out-2/bounding_box_2d_tight_prim_paths_0025.json', 'out-2/semantic_segmentation_0025.png', '
# ...

# %%
import os
len(os.listdir("data/out-2"))
# Out:
# 6001

# %%
import shutil
import os

# Define the source and destination directories
source_dir = "/content/data/out-2"
destination_dir = "/content/inmind-dl/FinalProject/raw_data"

# Move the directory or its contents to the destination
shutil.move(source_dir, destination_dir)
# Out:
# '/content/inmind-dl/FinalProject/raw_data'

# %%
import os
len(os.listdir("/content/inmind-dl/FinalProject/raw_data"))
# Out:
# 6001

# %% [markdown]
# # Organize dataset

# %%
# %cd inmind-dl/FinalProject
# !python /content/inmind-dl/FinalProject/organize_dataset.py
# !python organize_dataset.py
# Out:
# /content/inmind-dl/FinalProject
# Files have been successfully copied, organized, and renamed.

# %% [markdown]
# # Split dataset into train, test, val

# %%
# !python SemanticSegmentation/split.py
# Out:
# 100% 800/800 [00:04<00:00, 174.15it/s]
# 100% 100/100 [00:00<00:00, 277.13it/s]
# 100% 100/100 [00:00<00:00, 197.23it/s]

# %% [markdown]
# # Train Semantic Segmentation Model

# %%
# !cd ..

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 414 bytes | 207.00 KiB/s, done.
# From https://github.com/celinekaram/inmind-dl
#    7228cec..8f365e0  master     -> origin/master
# Updating 7228cec..8f365e0
# Fast-forward
#  FinalProject/SemanticSegmentation/train.py | 4 +---
#  1 file changed, 1 insertion(+), 3 deletions(-)

# %%
# %cd FinalProject
# Out:
# [Errno 2] No such file or directory: 'FinalProject'
# /content/inmind-dl/FinalProject

# %%
# !pwd
# Out:
# /content/inmind-dl/FinalProject

# %%
# !python SemanticSegmentation/train.py --batch_size 2 --learning_rate 0.0001 --load_memory 'true' --best_checkpoint 'SemanticSegmentation/models/epoch.pth' --num_epochs 1 --num_workers 2
# Out:
# 2024-08-22 18:51:16.924816: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-22 18:51:16.944967: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-22 18:51:16.950987: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-22 18:51:16.964904: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp /content/inmind-dl/FinalProject/SemanticSegmentation/models/epoch_0.pt /content/drive/MyDrive/

# %%
# !zip -r /content/logs.zip /content/inmind-dl/FinalProject/SemanticSegmentation/logs
from google.colab import files
files.download('/content/logs.zip')
# Out:
# updating: content/inmind-dl/FinalProject/SemanticSegmentation/logs/ (stored 0%)
# updating: content/inmind-dl/FinalProject/SemanticSegmentation/logs/events.out.tfevents.1724347590.71de0d688a04.5003.0 (deflated 70%)
# updating: content/inmind-dl/FinalProject/SemanticSegmentation/logs/events.out.tfevents.1724349827.71de0d688a04.5003.1 (deflated 68%)
# updating: content/inmind-dl/FinalProject/SemanticSegmentation/logs/events.out.tfevents.1724347519.71de0d688a04.4675.0 (deflated 9%)
#   adding: content/inmind-dl/FinalProject/SemanticSegmentation/logs/events.out.tfevents.1724352680.71de0d688a04.26898.0 (deflated 70%)
